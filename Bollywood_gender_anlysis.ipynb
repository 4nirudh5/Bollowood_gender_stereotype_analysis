# %% [markdown]
# ## **All the required libraries**
# ***for this project***

# %%
import pandas as pd 
import re
import string
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import datetime as dt
from nltk.probability import FreqDist
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## **Adjectives used to describe Female**

# %%
female_ad = pd.read_csv('/content/female_adjectives.csv',on_bad_lines='skip') 
female_ad.head()
# Out:
#    1970           [young]
# 0  1970                []
# 1  1970                []
# 2  1970                []
# 3  1970  [unrecognizable]
# 4  1970                []

# %%
female_ad.drop(['1970'], axis=1,inplace = True)

# %%
words =list( female_ad.values)
stopwords=['ourselves', 'hers','the','of','and','in', 'between', 'yourself', 'but', 'again','of', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than']
split_words=[]
for word in words:
    lo_w=[]
    list_of_words=str(word).split()
    for w in list_of_words:
        if w not in stopwords:
            lo_w.append(w)
    split_words.append(lo_w)
allwords = []
for wordlist in split_words:
    allwords += wordlist

# %%
#frequently used words
mostcommon = FreqDist(allwords).most_common(100)
wordcloud = WordCloud(width=1600, height=800, background_color='white', stopwords=STOPWORDS).generate(str(mostcommon))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top Common adjectives to describe female', fontsize=50)
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## **Adjectives used to describe Male**

# %%
male_ad = pd.read_csv('/content/male_adjectives.csv',on_bad_lines='skip') 
male_ad.head()
# Out:
#    1970            []
# 0  1970  [unhappilly]
# 1  1970            []
# 2  1970            []
# 3  1970      [famous]
# 4  1970            []

# %%
male_ad.drop(['1970'], axis=1,inplace = True)

# %%
words =list(male_ad.values)
stopwords=['ourselves', 'hers','the','of','and','in', 'between', 'yourself', 'but', 'again','of', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than']
split_words=[]
for word in words:
    lo_w=[]
    list_of_words=str(word).split()
    for w in list_of_words:
        if w not in stopwords:
            lo_w.append(w)
    split_words.append(lo_w)
allwords = []
for wordlist in split_words:
    allwords += wordlist

# %%
mostcommon = FreqDist(allwords).most_common(100)
wordcloud = WordCloud(width=1600, height=800, background_color='white', stopwords=STOPWORDS).generate(str(mostcommon))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top Common adjectives to describe male', fontsize=50)
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## **Verbs used to describe Female**

# %%
female_v = pd.read_csv('/content/female_verb.csv',on_bad_lines='skip') 
female_v.head()
# Out:
#    1970 [introduces]
# 0  1970    [decides]
# 1  1970      [moves]
# 2  1970      [plays]
# 3  1970      [meets]
# 4  1970           []

# %%
female_v.drop(['1970'], axis=1,inplace = True)

# %%
words =list(female_v.values)
stopwords=['ourselves', 'hers','the','of','and','in', 'between', 'yourself', 'but', 'again','of', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than']
split_words=[]
for word in words:
    lo_w=[]
    list_of_words=str(word).split()
    for w in list_of_words:
        if w not in stopwords:
            lo_w.append(w)
    split_words.append(lo_w)
allwords = []
for wordlist in split_words:
    allwords += wordlist

# %%
mostcommon = FreqDist(allwords).most_common(100)
wordcloud = WordCloud(width=1600, height=800, background_color='white', stopwords=STOPWORDS).generate(str(mostcommon))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top Common verbs to describe female', fontsize=50)
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## **Verbs used to describe Male**

# %%
male_v = pd.read_csv('/content/male_verb.csv',on_bad_lines='skip') 
male_v.head()
# Out:
#    1970 [convinces]
# 0  1970          []
# 1  1970     [lives]
# 2  1970     [lives]
# 3  1970          []
# 4  1970          []

# %%
male_v.drop(['1970'], axis=1,inplace = True)

# %%
words =list(male_v.values)
stopwords=['ourselves', 'hers','the','of','and','in', 'between', 'yourself', 'but', 'again','of', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than']
split_words=[]
for word in words:
    lo_w=[]
    list_of_words=str(word).split()
    for w in list_of_words:
        if w not in stopwords:
            lo_w.append(w)
    split_words.append(lo_w)
allwords = []
for wordlist in split_words:
    allwords += wordlist

# %%
mostcommon = FreqDist(allwords).most_common(100)
wordcloud = WordCloud(width=1600, height=800, background_color='white', stopwords=STOPWORDS).generate(str(mostcommon))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top Common verbs to describe male', fontsize=50)
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## **Gender mention centrality**

# %%
female_mc = pd.read_csv("/content/female_mentions_centrality.csv",on_bad_lines='skip')
female_mc.head()
# Out:
#        MOVIE_NAME     CAST   MENTIONS   TOTAL_CENTRALITY   COUNT  \
# 0  Aan Milo Sajna    woman        2.0         222.500000    12.0
# 1  Aan Milo Sajna  savitri       11.0         868.166667   131.0
# 2  Aan Milo Sajna  deepali        4.0           0.000000    89.0
# 3       Abhinetri   anjana        9.0         319.000000    79.0
# 4   Aag Aur Shola     usha        6.0          48.000000    54.0
#
#     AVERAGE_CENTRALITY
# 0            18.541667
# 1             6.627226
# 2             0.000000
# 3             4.037975
# 4             0.888889

# %%
male_mc = pd.read_csv("/content/male_mentions_centrality.csv",on_bad_lines='skip')
male_mc.head()
# Out:
#        MOVIE_NAME    CAST   MENTIONS   TOTAL_CENTRALITY   COUNT  \
# 0  Aan Milo Sajna    anil       13.0        9219.200000   131.0
# 1         Bachpan     tom       11.0          29.000000    59.0
# 2         Bachpan  father        5.0         469.333333    63.0
# 3         Bachpan   rahim        2.0           0.000000    29.0
# 4   Aag Aur Shola  nagesh        4.0          94.000000    38.0
#
#     AVERAGE_CENTRALITY
# 0            70.375573
# 1             0.491525
# 2             7.449735
# 3             0.000000
# 4             2.473684

# %%
female_mc.describe()
# Out:
#           MENTIONS   TOTAL_CENTRALITY        COUNT   AVERAGE_CENTRALITY
# count  5043.000000        5043.000000  5043.000000          5043.000000
# mean      7.049375         385.929784    77.468372             4.955029
# std      10.352712         882.565299    92.716353             6.571231
# min       0.000000           0.000000     0.000000             0.000000
# 25%       1.000000          38.000000    20.000000             1.252358
# 50%       3.000000         138.000000    45.000000             3.129032
# 75%       9.000000         390.750000    99.000000             6.202941
# max     128.000000       20080.269910  1012.000000            91.600980

# %%
male_mc.describe()
# Out:
#           MENTIONS   TOTAL_CENTRALITY        COUNT   AVERAGE_CENTRALITY
# count  9348.000000        9348.000000  9348.000000          9348.000000
# mean      7.319855         461.064942    86.618635             4.810756
# std      10.799919        2926.885729   106.718036            18.233392
# min       0.000000           0.000000     0.000000             0.000000
# 25%       1.000000          24.578571    23.000000             0.783574
# 50%       4.000000         136.000000    51.000000             2.729289
# 75%       9.000000         416.683333   108.000000             5.683440
# max     120.000000      260924.611400  1702.000000          1562.422823

# %% [markdown]
# *   Male MENTIONS is 0.27048 higher
# *   Male TOTAL CENTRALITY is 75.1355158 higher
# *   Male COUNT is 9.150263 higher
# *   Male AVERAGE CENTRALITY is -0.144273 lower

# %%
for i, predictor in enumerate(female_mc):
    plt.figure(i)
    sns.displot(data=female_mc, x=predictor)

# %%
for i, predictor in enumerate(male_mc):
    plt.figure(i)
    sns.countplot(data=male_mc, x=predictor)

# %% [markdown]
# ## **Gender centrality**

# %%
male_c = pd.read_csv("/content/male_centrality.csv",on_bad_lines='skip')
male_c.head()
# Out:
#        Movie_Name  Cast_Name   Total_Centrality   Average_Centrality
# 0  Aan Milo Sajna       anil        9219.200000            70.375573
# 1         Bachpan        tom          29.000000             0.491525
# 2         Bachpan     father         469.333333             7.449735
# 3         Bachpan      rahim           0.000000             0.000000
# 4   Aag Aur Shola     nagesh          94.000000             2.473684

# %%
female_c = pd.read_csv("/content/female_centrality.csv",on_bad_lines='skip')
female_c.head()
# Out:
#        Movie_Name  Cast_Name   Total_Centrality   Average_Centrality
# 0  Aan Milo Sajna      woman         222.500000            18.541667
# 1  Aan Milo Sajna    savitri         868.166667             6.627226
# 2  Aan Milo Sajna    deepali           0.000000             0.000000
# 3       Abhinetri     anjana         319.000000             4.037975
# 4   Aag Aur Shola       usha          48.000000             0.888889

# %%
male_c.describe()
# Out:
#         Total_Centrality   Average_Centrality
# count        9348.000000          9348.000000
# mean          461.064942             4.810756
# std          2926.885729            18.233392
# min             0.000000             0.000000
# 25%            24.578571             0.783574
# 50%           136.000000             2.729289
# 75%           416.683333             5.683440
# max        260924.611400          1562.422823

# %%
female_c.describe()
# Out:
#         Total_Centrality   Average_Centrality
# count        5043.000000          5043.000000
# mean          385.929784             4.955029
# std           882.565299             6.571231
# min             0.000000             0.000000
# 25%            38.000000             1.252358
# 50%           138.000000             3.129032
# 75%           390.750000             6.202941
# max         20080.269910            91.600980

# %% [markdown]
# Total centrality is higher for male

# %%
sns.lineplot(data = male_c[' Total_Centrality'])
plt.show()

# %%
sns.lineplot(data = male_c[' Average_Centrality'])
plt.show()

# %%
sns.lineplot(data = female_c[' Total_Centrality'])
plt.show()

# %%
sns.lineplot(data = female_c[' Average_Centrality'])
plt.show()

# %% [markdown]
# ## **Gender in songs**

# %%
songsdb = pd.read_csv('/content/songsDB.csv',on_bad_lines='skip')
songsdb.head()
# Out:
#        movieTitle_year      singer_name  gender  song_count
# 0    Aag Aur Daag_1970      Asha Bhosle  FEMALE           3
# 1    Aag Aur Daag_1970    Mohammed Rafi    MALE           1
# 2  Aan Milo Sajna_1970    Kishore Kumar    MALE           2
# 3  Aan Milo Sajna_1970  Lata Mangeshkar  FEMALE           3
# 4  Aan Milo Sajna_1970    Mohammed Rafi    MALE           2

# %%
songsf = pd.read_csv('/content/songsFrequency.csv',on_bad_lines='skip')
songsf.head()
# Out:
#                          MOVIE_NAME   YEAR   MALE_SINGER_COUNT  \
# 0                Raabta (film)_2017   2017                   5
# 1                 Luv U Soniyo_2013   2013                   4
# 2                     Sahibaan_1993   1993                   2
# 3  Baap Numbri Beta Dus Numbri_1990   1990                   1
# 4             Jyoti Bane Jwala_1980   1980                   3
#
#     FEMALE_SINGER_COUNT   MALE_SONG_COUNT   FEMALE_SONG_COUNT
# 0                     2                 8                   2
# 1                     1                 6                   1
# 2                     2                 3                   6
# 3                     2                 1                   4
# 4                     3                 4                   5

# %%
for i, predictor in enumerate(songsdb.drop(columns=['movieTitle_year','singer_name'])):
    plt.figure(i)
    sns.countplot(data=songsdb, x=predictor, hue='gender')

# %%
for i, predictor in enumerate(songsf):
    plt.figure(i)
    sns.countplot(data=songsf, x=predictor) #hue='gender')

# %%
for i, predictor in enumerate(songsdb):
    plt.figure(i)
    sns.countplot(data=songsdb, x=predictor) #hue='gender')

# %%
sns.pairplot(data = songsf)
plt.show()

# %% [markdown]
# ## **Creating model**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split 
import pickle

# %%
female_mc.head()
# Out:
#        MOVIE_NAME     CAST   MENTIONS   TOTAL_CENTRALITY   COUNT  \
# 0  Aan Milo Sajna    woman        2.0         222.500000    12.0
# 1  Aan Milo Sajna  savitri       11.0         868.166667   131.0
# 2  Aan Milo Sajna  deepali        4.0           0.000000    89.0
# 3       Abhinetri   anjana        9.0         319.000000    79.0
# 4   Aag Aur Shola     usha        6.0          48.000000    54.0
#
#     AVERAGE_CENTRALITY
# 0            18.541667
# 1             6.627226
# 2             0.000000
# 3             4.037975
# 4             0.888889

# %%
female_mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5048 entries, 0 to 5047
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MOVIE_NAME           5048 non-null   object
#  1    CAST                5036 non-null   object
#  2    MENTIONS            5043 non-null   float64
#  3    TOTAL_CENTRALITY    5043 non-null   float64
#  4    COUNT               5043 non-null   float64
#  5    AVERAGE_CENTRALITY  5043 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 236.8+ KB

# %%
female_mc.isnull().sum()
# Out:
# MOVIE_NAME              0
#  CAST                  12
#  MENTIONS               5
#  TOTAL_CENTRALITY       5
#  COUNT                  5
#  AVERAGE_CENTRALITY     5
# dtype: int64

# %%
female_mc.isnull().any()
# Out:
# MOVIE_NAME             False
#  CAST                   True
#  MENTIONS               True
#  TOTAL_CENTRALITY       True
#  COUNT                  True
#  AVERAGE_CENTRALITY     True
# dtype: bool

# %%
female_mc.dropna(inplace=True)

# %%
x = female_mc.iloc[:,2:5]
y = female_mc.iloc[:,[5]]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
regressor= RandomForestRegressor()  
regressor.fit(x_train, y_train) 
y_pred = regressor.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
regressor.score(x_test,y_test)
# Out:
# 0.98801998341913

# %%
filename = 'randomforestreg.sav'
pickle.dump(regressor, open(filename, 'wb'))
